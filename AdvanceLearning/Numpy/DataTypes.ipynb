# %%
# there are several types of datatypes in numpy  Some common datatypes are listed below 
"""
Intergers : int32, int64
Floating point nums: float32, float64 
Boolean : bool
Complex nums: complex64, complex128
String : s(byte-str)& U (unicode-str)
Object : generic python objects
"""
# Out:
# hello world
