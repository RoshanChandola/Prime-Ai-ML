# %%
import numpy as np
#properties 
arr=np.array([1,2,3,4,5])
print(arr.shape)#dimesion of array 

print(arr.size)# number of elements in array

print(arr.dtype) # datatype of stored elements in array

float_arr= arr.astype(np.float64)# changin the datatype of array
print(float_arr.dtype)
# Out:
# (5,)
# 5
# int64
# float64
