# %%
import numpy as np
#vectorization
arr=np.array([1,2,3,4])
print(arr**2)
print(arr+10)
# Out:
# [ 1  4  9 16]
# [11 12 13 14]

# %%
# BroadCasting : to enable efficient and concise element-wise operations on arrays with different, but compatible, shapes
#performing mathematical operations on incompatible sizes (basically scaling smaller arrays
print(arr+10)
