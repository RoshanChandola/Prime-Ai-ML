# %%
import seaborn as sns
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(
    n_samples=1000,
    n_features=2,
    centers=4,
    random_state=42
)

# %%
sns.scatterplot(x=X[:,0],y=X[:,1],c=y)
# Out:
# <Axes: >

# %%
# implementing kmeans clustering
from sklearn .cluster import KMeans

# %%
K = 4
Kmeans = KMeans(
    n_clusters=K,
    random_state=42,
    init='k-means++'
    )

lables =Kmeans.fit_predict(X)

# %%
sns.scatterplot(x=X[:,0],y=X[:,1], c=lables)
# Out:
# <Axes: >

# %% [markdown]
# ### choose our K value using elbow, silhouette score

# %%
# elbow method

wcss =[]

for k in range (1,21):
    kmeans = KMeans(n_clusters = k)
    kmeans.fit_predict(X)
    wcss.append(kmeans.inertia_)

# %%
sns.lineplot(x=range(1,21),y=wcss,marker='o')
# Out:
# <Axes: >

# %%
# kneed Module
# !pip install kneed
# Out:
# Requirement already satisfied: kneed in C:\Users\sc790\anaconda3\Lib\site-packages (0.8.6)
# Requirement already satisfied: numpy>=1.14.2 in C:\Users\sc790\anaconda3\Lib\site-packages (from kneed) (2.1.3)
# Requirement already satisfied: scipy>=1.0.0 in C:\Users\sc790\anaconda3\Lib\site-packages (from kneed) (1.15.3)

# %%
from kneed import KneeLocator

knee = KneeLocator(range(1,21),wcss,curve='convex',direction='decreasing')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from kneed import KneeLocator
#       2
#       3 knee = KneeLocator(range(1,21),wcss,curve='convex',direction='decreasing')
#
# ModuleNotFoundError: No module named 'kneed'

# %%
print("optimal clusterS",knee.elbow)

# %% [markdown]
# #### silhouetter score

# %%
from sklearn.metrics import silhouette_score
ss =[]

for k in range (2,21):
    kmeans = KMeans(n_clusters = k)
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels)
    ss.append(score)

# %%
# plot - k and ss

sns.lineplot(x=range(2,21),y=ss,marker='o')
