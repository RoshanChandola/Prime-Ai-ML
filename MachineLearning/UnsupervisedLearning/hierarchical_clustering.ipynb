# %%
from sklearn.datasets import load_iris
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()
X = iris.data
y= iris.target

# %%
#scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#visulization
sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:,2])
# Out:
# <Axes: >

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

#linkage matrix
Z = linkage(X_scaled, method='ward') # method ward minimizes the variance of clusters being merged. different methods can be used like single, complete, average, weighted, centroid, median, ward

#dendrogram
plt.figure(figsize=(12, 6))
dendrogram(Z)
plt.xlabel('Sample index')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram')
# Out:
# Text(0.5, 1.0, 'Hierarchical Clustering Dendrogram')

# %%
# code for agglerative clustering
from sklearn.cluster import AgglomerativeClustering

clustering = AgglomerativeClustering(n_clusters=2)
labels = clustering.fit_predict(X_scaled)

sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:,2], c= labels)
# Out:
# <Axes: >
